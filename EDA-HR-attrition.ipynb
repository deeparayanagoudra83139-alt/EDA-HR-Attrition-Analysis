# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set styles for plots
sns.set(style='whitegrid', palette='Set2')

print("Libraries imported successfully")
# Out:
# Libraries imported successfully

# %%
df = pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv')
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df = pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv')
#       2 print(df.head())
#
# File ~\anaconda3\python\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\user

# %%
import os
os.chdir(r'C:\Users\user\Desktop\data 1')
print("Current working directory changed to:", os.getcwd())
# Out:
# Current working directory changed to: C:\Users\user\Desktop\data 1

# %%
df = pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv')
print("Dataset loaded successfully ✅")
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df = pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv')
#       2 print("Dataset loaded successfully ✅")
#       3 df.head()
#
# ...

# %%
df = pd.read_csv(r'C:\Users\user\Desktop\data 1\WA_Fn-UseC_-HR-Employee-Attrition.csv')
print("Dataset loaded successfully ✅")
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df = pd.read_csv(r'C:\Users\user\Desktop\data 1\WA_Fn-UseC_-HR-Employee-Attrition.csv')
#       2 print("Dataset loaded successfully ✅")
#       3 df.head()
#
# ...

# %%
df = pd.read_csv(r'C:\Users\user\Desktop\data 1\WA_Fn-UseC_-HR-Employee-Attrition.csv')
print("Dataset loaded successfully ✅")
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df = pd.read_csv(r'C:\Users\user\Desktop\data 1\WA_Fn-UseC_-HR-Employee-Attrition.csv')
#       2 print("Dataset loaded successfully ✅")
#       3 df.head()
#
# ...

# %%
import os
os.chdir(r'C:\Users\user\Desktop\data 1')
print("Current folder:", os.getcwd())
print("Files Jupyter can see:")
print(os.listdir())
# Out:
# Current folder: C:\Users\user\Desktop\data 1
# Files Jupyter can see:
# ['EDA_hr.py', 'WA_Fn-UseC_-HR-Employee-Attrition.csv.lnk']

# %%
import os
import glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# nicer plots in Jupyter
# %matplotlib inline
pd.set_option('display.max_columns', 200)
pd.set_option('display.width', 240)
sns.set(style="whitegrid")

# %%
print("Current folder:", os.getcwd())
print("Files here:")
for f in os.listdir():
    print("  ", f)

# Also show any CSV files under this folder (recursively optional)
print("\nCSV files in current folder and subfolders:")
for f in glob.glob("*/.csv", recursive=True):
    print("  ", f)
# Out:
# Current folder: C:\Users\user
# Files here:
#    .anaconda
#    .conda
#    .condarc
#    .continuum
#    .gitconfig
#    .idlerc
#    .ipynb_checkpoints
#    .ipython
#    .jupyter
#    .lesshst
#    .matplotlib
#    .python_history
#    .vscode
#    1NPDPRO5.DOC
#    3D Objects
#    anaconda3
#    AppData
#    Application Data
#    Contacts
#    Cookies
#    Desktop
#    Documents
#    Downloads
#    Favorites
#    IntelGraphicsProfiles
#    Links
#    Local Settings
#    Microsoft
#    Music
#    My Documents
#    NetHood
#    NPProt.bkp
#    NPProt.exe
#    NTUSER.DAT
#    ntuser.dat.LOG1
#    ntuser.dat.LOG2
#    NTUSER.DAT{53b39e87-18c4-11ea-a811-000d3aa4692b}.TxR.0.regtrans-ms
#    NTUSER.DAT{53b39e87-18c4-11ea-a811-000d3aa4692b}.TxR.1.regtrans-ms
#    NTUSER.DAT{53b39e87-18c4-11ea-a811-000d3aa4692b}.TxR.2.regtrans-ms
#    NTUSER.DAT{53b39e87-18c4-11ea-a811-000d3aa4692b}.TxR.blf
#    NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TM.blf
# ...

# %%
import os

# Change directory to where your data file is
os.chdir(r'C:\Users\user\Desktop\data 1')

# Confirm the change
print("Current folder:", os.getcwd())
print("Files Jupyter can see:", os.listdir())
# Out:
# Current folder: C:\Users\user\Desktop\data 1
# Files Jupyter can see: ["'WA_Fn-UseC_-HR-Employee-Attrition.csv.lnk'.lnk", 'EDA_hr.py']

# %%
import pandas as pd

# Path to the real CSV (from Downloads)
df = pd.read_csv(r'C:\Users\user\Downloads\WA_Fn-UseC_-HR-Employee-Attrition.csv')

print("✅ Dataset loaded successfully!")
df.head()
# Out:
# ✅ Dataset loaded successfully!
#    Age Attrition     BusinessTravel  DailyRate              Department  DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0   41       Yes      Travel_Rarely       1102                   Sales                 1          2  Life Sciences              1               1                        2  Female          94               3         2
# 1   49        No  Travel_Frequently        279  Research & Development                 8          1  Life Sciences              1               2                        3    Male          61               2         2
# 2   37       Yes      Travel_Rarely       1373  Research & Development                 2          2          Other              1               4                        4    Male          92               2         1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.describe(include='all').T
# Out:
#                            count unique                     top  freq          mean          std     min     25%      50%      75%      max
# Age                       1470.0    NaN                     NaN   NaN      36.92381     9.135373    18.0    30.0     36.0     43.0     60.0
# Attrition                   1470      2                      No  1233           NaN          NaN     NaN     NaN      NaN      NaN      NaN
# BusinessTravel              1470      3           Travel_Rarely  1043           NaN          NaN     NaN     NaN      NaN      NaN      NaN
# DailyRate                 1470.0    NaN                     NaN   NaN    802.485714     403.5091   102.0   465.0    802.0   1157.0   1499.0
# Department                  1470      3  Research & Development   961           NaN          NaN     NaN     NaN      NaN      NaN      NaN
# DistanceFromHome          1470.0    NaN                     NaN   NaN      9.192517     8.106864     1.0     2.0      7.0     14.0     29.0
# ...

# %%
missing = df.isnull().sum().sort_values(ascending=False)
missing[missing > 0]
# Out:
# Series([], dtype: int64)

# %%
print("Duplicate rows:", df.duplicated().sum())
# Out:
# Duplicate rows: 0

# %%
print(df.columns.tolist())
df.head()
# Out:
# ['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount', 'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']
#    Age Attrition     BusinessTravel  DailyRate              Department  DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
df.nunique().sort_values(ascending=True)
# Out:
# Over18                         1
# StandardHours                  1
# EmployeeCount                  1
# Gender                         2
# Attrition                      2
# PerformanceRating              2
# OverTime                       2
# MaritalStatus                  3
# Department                     3
# BusinessTravel                 3
# StockOptionLevel               4
# EnvironmentSatisfaction        4
# JobInvolvement                 4
# JobSatisfaction                4
# RelationshipSatisfaction       4
# WorkLifeBalance                4
# Education                      5
# JobLevel                       5
# EducationField                 6
# TrainingTimesLastYear          7
# JobRole                        9
# NumCompaniesWorked            10
# PercentSalaryHike             15
# YearsSinceLastPromotion       16
# YearsWithCurrManager          18
# YearsInCurrentRole            19
# DistanceFromHome              29
# YearsAtCompany                37
# ...

# %%
df.columns = df.columns.str.strip().str.replace(' ', '').str.replace('-', '')
df.head(3)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0   41       Yes      Travel_Rarely       1102                   Sales                 1          2  Life Sciences              1               1                        2  Female          94               3         2
# 1   49        No  Travel_Frequently        279  Research & Development                 8          1  Life Sciences              1               2                        3    Male          61               2         2
# 2   37       Yes      Travel_Rarely       1373  Research & Development                 2          2          Other              1               4                        4    Male          92               2         1
#
# ...

# %%
df.to_csv('Employee_Attrition_Cleaned.csv', index=False)
print("Cleaned dataset saved ✅")
# Out:
# Cleaned dataset saved ✅

# %%
sns.countplot(x='Attrition', data=df)
plt.title('Employee Attrition Distribution')
plt.xlabel('Attrition')
plt.ylabel('Count')
plt.show()

# Percentage values
attrition_percent = df['Attrition'].value_counts(normalize=True) * 100
print(attrition_percent)
# Out:
# Attrition
# No     83.877551
# Yes    16.122449
# Name: proportion, dtype: float64

# %%
for col in categorical_cols:
    plt.figure(figsize=(7,3))
    sns.countplot(x=col, hue='Attrition', data=df)
    plt.title(f'{col} vs Attrition')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 for col in categorical_cols:
#       2     plt.figure(figsize=(7,3))
#       3     sns.countplot(x=col, hue='Attrition', data=df)
#
# NameError: name 'categorical_cols' is not defined

# %%
categorical_cols = ['Department', 'JobRole', 'Gender', 'MaritalStatus', 'EducationField']

for col in categorical_cols:
    plt.figure(figsize=(7,3))
    sns.countplot(x=col, hue='Attrition', data=df)
    plt.title(f'{col} vs Attrition')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %%
numeric_cols = ['Age', 'MonthlyIncome', 'DistanceFromHome', 'YearsAtCompany', 'YearsInCurrentRole']

df[numeric_cols].hist(bins=20, figsize=(10,8), color='skyblue', edgecolor='black')
plt.suptitle("Numeric Variable Distributions", y=1.02)
plt.tight_layout()
plt.show()

# %%
for col in numeric_cols:
    plt.figure(figsize=(6,3))
    sns.boxplot(x='Attrition', y=col, data=df)
    plt.title(f'{col} by Attrition')
    plt.show()

# %%
corr = df.corr(numeric_only=True)
plt.figure(figsize=(12,8))
sns.heatmap(corr, cmap='coolwarm', center=0)
plt.title('Correlation Heatmap of Numeric Features')
plt.show()

# %%
df['Attrition_flag'] = df['Attrition'].map({'Yes':1, 'No':0})

correlations = df.corr(numeric_only=True)['Attrition_flag'].sort_values(ascending=False)
print(correlations)
# Out:
# Attrition_flag              1.000000
# DistanceFromHome            0.077924
# NumCompaniesWorked          0.043494
# MonthlyRate                 0.015170
# PerformanceRating           0.002889
# HourlyRate                 -0.006846
# EmployeeNumber             -0.010577
# PercentSalaryHike          -0.013478
# Education                  -0.031373
# YearsSinceLastPromotion    -0.033019
# RelationshipSatisfaction   -0.045872
# DailyRate                  -0.056652
# TrainingTimesLastYear      -0.059478
# WorkLifeBalance            -0.063939
# EnvironmentSatisfaction    -0.103369
# JobSatisfaction            -0.103481
# JobInvolvement             -0.130016
# YearsAtCompany             -0.134392
# StockOptionLevel           -0.137145
# YearsWithCurrManager       -0.156199
# Age                        -0.159205
# MonthlyIncome              -0.159840
# YearsInCurrentRole         -0.160545
# JobLevel                   -0.169105
# TotalWorkingYears          -0.171063
# ...

# %%
df.to_csv(r'C:\Users\user\Desktop\data 1\Employee_Attrition_Cleaned.csv', index=False)
print("✅ Cleaned dataset saved successfully!")
# Out:
# ✅ Cleaned dataset saved successfully!

# %% [markdown]
# - Most employees did not leave (Attrition ≈ 84% No, 16% Yes)
# - Younger employees (Age < 35) show higher attrition rates
# - Employees with lower Monthly Income and fewer Years at Company tend to leave more
# - Certain job roles (e.g., Sales Executive, Laboratory Technician) have higher attrition
# - MonthlyIncome is positively correlated with TotalWorkingYears
# - DistanceFromHome has weak correlation with Attrition
